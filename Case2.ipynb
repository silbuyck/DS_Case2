# %%
import streamlit as st
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("athlete_events.csv")

# %%
df.drop(df[df['Season'] == 'Winter'].index, inplace = True)
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 26         Netherlands  NED  1932 Summer  1932  Summer     Los Angeles
# ...                ...  ...          ...   ...     ...             ...
# 271106       Argentina  ARG  2004 Summer  2004  Summer          Athina
# 271107   United States  USA  1972 Summer  1972  Summer          Munich
# 271108          Russia  RUS  2000 Summer  2000  Summer          Sydney
# 271109          Russia  RUS  2004 Summer  2004  Summer          Athina
# 271110         Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                   Event Medal
# 0       Basketball             Basketball Men's Basketball   NaN
# 1             Judo            Judo Men's Extra-Lightweight   NaN
# 2         Football                 Football Men's Football   NaN
# 3       Tug-Of-War             Tug-Of-War Men's Tug-Of-War  Gold
# 26       Athletics            Athletics Women's 100 metres   NaN
# ...            ...                                     ...   ...
# 271106      Hockey                     Hockey Men's Hockey   NaN
# 271107    Football                 Football Men's Football   NaN
# 271108      Rowing  Rowing Men's Lightweight Coxless Fours   NaN
# 271109      Rowing  Rowing Men's Lightweight Coxless Fours   NaN
# 271110  Basketball           Basketball Women's Basketball   NaN
#
# [222552 rows x 15 columns]

# %%
df6 = pd.unique(df['City'])
df6
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Los Angeles',
#        'Helsinki', 'Sydney', 'Atlanta', 'Stockholm', 'Beijing',
#        'Rio de Janeiro', 'Athina', 'Mexico City', 'Munich', 'Seoul',
#        'Berlin', 'Melbourne', 'Roma', 'Amsterdam', 'Montreal', 'Moskva',
#        'Tokyo', 'St. Louis'], dtype=object)

# %%
for x in df6
# Out:
#   Input In [64]
#     for x in df6
#                 ^
# SyntaxError: invalid syntax

# %%
import requests
response_list = []
for city in df6: 
    print(city)


    api_url = 'https://api.api-ninjas.com/v1/city?name={}'.format(city)
    response = requests.get(api_url, headers={'X-Api-Key': '0eJ24h1oAq0DwwYAz67D3Q==EaKYACEsoPSFRO2M'})
    if response.status_code == requests.codes.ok:
        print(response.text)
    else:
        print("Error:", response.status_code, response.text[1:-1])
    response = response.text[1:-1]
    response = response
    response_list.append(response)
# Out:
# Barcelona
# [{"name": "Barcelona", "latitude": 41.3825, "longitude": 2.1769, "country": "ES", "population": 4588000, "is_capital": false}]
# London
# [{"name": "London", "latitude": 51.5072, "longitude": -0.1275, "country": "GB", "population": 10979000, "is_capital": true}]
# Antwerpen
# []
# Paris
# [{"name": "Paris", "latitude": 48.8566, "longitude": 2.3522, "country": "FR", "population": 11020000, "is_capital": true}]
# Los Angeles
# [{"name": "Los Angeles", "latitude": 34.1139, "longitude": -118.407, "country": "US", "population": 12750807, "is_capital": false}]
# Helsinki
# [{"name": "Helsinki", "latitude": 60.1756, "longitude": 24.9342, "country": "FI", "population": 642045, "is_capital": true}]
# Sydney
# [{"name": "Sydney", "latitude": -33.865, "longitude": 151.209, "country": "AU", "population": 5312163, "is_capital": false}]
# Atlanta
# [{"name": "Atlanta", "latitude": 33.7627, "longitude": -84.4224, "country": "US", "population": 5449398, "is_capital": false}]
# Stockholm
# [{"name": "Stockholm", "latitude": 59.3294, "longitude": 18.0686, "country": "SE", "population": 972647, "is_capital": true}]
# Beijing
# [{"name": "Beijing", "latitude": 39.905, "longitude": 116.391, "country": "CN", "population": 19433000, "is_capital": true}]
# Rio de Janeiro
# [{"name": "Rio De Janeiro", "latitude": -22.9083, "longitude": -43.1964, "country": "BR", "population": 12272000, "is_capital": false}]
# Athina
# []
# Mexico City
# [{"name": "Mexico City", "latitude": 19.4333, "longitude": -99.1333, "country": "MX", "population": 20996000, "is_capital": true}]
# Munich
# [{"name": "Munich", "latitude": 48.1372, "longitude": 11.5755, "country": "DE", "population": 1471508, "is_capital": false}]
# Seoul
# [{"name": "Seoul", "latitude": 37.5833, "longitude": 127.0, "country": "KR", "population": 21794000, "is_capital": true}]
# Berlin
# [{"name": "Berlin", "latitude": 52.5167, "longitude": 13.3833, "country": "DE", "population": 3644826, "is_capital": true}]
# Melbourne
# [{"name": "Melbourne", "latitude": -37.8136, "longitude": 144.963, "country": "AU", "population": 5078193, "is_capital": false}]
# Roma
# [{"name": "Kostroma", "latitude": 57.7667, "longitude": 40.9333, "country": "RU", "population": 277648, "is_capital": false}]
# Amsterdam
# [{"name": "Amsterdam", "latitude": 52.35, "longitude": 4.9166, "country": "NL", "population": 1031000, "is_capital": true}]
# Montreal
# [{"name": "Montreal", "latitude": 45.5089, "longitude": -73.5617, "country": "CA", "population": 3519595, "is_capital": false}]
# Moskva
# []
# Tokyo
# [{"name": "Tokyo", "latitude": 35.6897, "longitude": 139.692, "country": "JP", "population": 37977000, "is_capital": true}]
# St. Louis
# [{"name": "St. Louis", "latitude": 38.6358, "longitude": -90.2451, "country": "US", "population": 2024074, "is_capital": false}]

# %%
response_list
# Out:
# ['{"name": "Barcelona", "latitude": 41.3825, "longitude": 2.1769, "country": "ES", "population": 4588000, "is_capital": false}',
#  '{"name": "London", "latitude": 51.5072, "longitude": -0.1275, "country": "GB", "population": 10979000, "is_capital": true}',
#  '',
#  '{"name": "Paris", "latitude": 48.8566, "longitude": 2.3522, "country": "FR", "population": 11020000, "is_capital": true}',
#  '{"name": "Los Angeles", "latitude": 34.1139, "longitude": -118.407, "country": "US", "population": 12750807, "is_capital": false}',
#  '{"name": "Helsinki", "latitude": 60.1756, "longitude": 24.9342, "country": "FI", "population": 642045, "is_capital": true}',
#  '{"name": "Sydney", "latitude": -33.865, "longitude": 151.209, "country": "AU", "population": 5312163, "is_capital": false}',
#  '{"name": "Atlanta", "latitude": 33.7627, "longitude": -84.4224, "country": "US", "population": 5449398, "is_capital": false}',
#  '{"name": "Stockholm", "latitude": 59.3294, "longitude": 18.0686, "country": "SE", "population": 972647, "is_capital": true}',
#  '{"name": "Beijing", "latitude": 39.905, "longitude": 116.391, "country": "CN", "population": 19433000, "is_capital": true}',
#  '{"name": "Rio De Janeiro", "latitude": -22.9083, "longitude": -43.1964, "country": "BR", "population": 12272000, "is_capital": false}',
#  '',
#  '{"name": "Mexico City", "latitude": 19.4333, "longitude": -99.1333, "country": "MX", "population": 20996000, "is_capital": true}',
#  '{"name": "Munich", "latitude": 48.1372, "longitude": 11.5755, "country": "DE", "population": 1471508, "is_capital": false}',
#  '{"name": "Seoul", "latitude": 37.5833, "longitude": 127.0, "country": "KR", "population": 21794000, "is_capital": true}',
#  '{"name": "Berlin", "latitude": 52.5167, "longitude": 13.3833, "country": "DE", "population": 3644826, "is_capital": true}',
#  '{"name": "Melbourne", "latitude": -37.8136, "longitude": 144.963, "country": "AU", "population": 5078193, "is_capital": false}',
#  '{"name": "Kostroma", "latitude": 57.7667, "longitude": 40.9333, "country": "RU", "population": 277648, "is_capital": false}',
#  '{"name": "Amsterdam", "latitude": 52.35, "longitude": 4.9166, "country": "NL", "population": 1031000, "is_capital": true}',
#  '{"name": "Montreal", "latitude": 45.5089, "longitude": -73.5617, "country": "CA", "population": 3519595, "is_capital": false}',
#  '',
#  '{"name": "Tokyo", "latitude": 35.6897, "longitude": 139.692, "country": "JP", "population": 37977000, "is_capital": true}',
#  '{"name": "St. Louis", "latitude": 38.6358, "longitude": -90.2451, "country": "US", "population": 2024074, "is_capital": false}']

# %%
sns.violinplot(data=df, x="Age", y="Medal", hue="Season", split=Truea)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 sns.violinplot(data=df, x="Age", y="Medal", hue="Season", split=True)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2400, in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2388 @_deprecate_positional_args
#    2389 def violinplot(
#    2390     *,
#    (...)
#    2397     ax=None, **kwargs,
#    2398 ):
# -> 2400     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2401                              bw, cut, scale, scale_hue, gridsize,
#    2402                              width, inner, split, dodge, orient, linewidth,
#    2403                              color, palette, saturation)
#    2405     if ax is None:
#    2406         ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:541, in _ViolinPlotter.__init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     539 if split and self.hue_names is not None and len(self.hue_names) != 2:
#     540     msg = "There must be exactly two hue levels to use `split`.'"
# --> 541     raise ValueError(msg)
#     542 self.split = split
#     544 if linewidth is None:
#
# ValueError: There must be exactly two hue levels to use `split`.'

# %%
sns.boxplot(data=df, x="Age", y="Season")

# %%
sns.countplot(data=df, x=df["Sex"])

# %%
df_unique_noc = df["NOC"].unique()
print(df_unique_country)

# %%
df_unique_country = df["Team"].unique()
print(df_unique_country)
# Out:
# ['Netherlands' 'United States' 'Finland' 'Norway' 'Estonia' 'Pakistan'
#  'Iran' 'Italy' 'Japan-1' 'Japan' 'Canada' 'West Germany' 'Argentina'
#  'Sweden' 'United States Virgin Islands' 'Switzerland' 'France-1'
#  'Ukraine' 'Latvia' 'Spain' 'Lebanon' 'Georgia' 'Belarus' 'Russia'
#  'Croatia' 'Russia-2' 'Russia-1' 'Bulgaria' 'Germany' 'Poland' 'France-2'
#  'Romania' 'Soviet Union' 'Switzerland-2' 'Switzerland-1' 'Australia'
#  'Great Britain-1' 'Czechoslovakia' 'Czech Republic' 'Great Britain'
#  'East Germany' 'France' 'Germany-2' 'Kazakhstan' 'Belgium' 'Togo'
#  'Turkey' 'Uzbekistan' 'Great Britain-2' 'United States-1'
#  'United States-2' 'Argentina-2' 'Trinidad and Tobago' 'South Korea'
#  'Sweden-2' 'Sweden-1' 'India' 'Italy-2' 'Morocco' 'Denmark' 'Canada-2'
#  'Canada-1' 'Austria' 'Yugoslavia' 'Soviet Union-2' 'Soviet Union-1'
#  'Monaco' 'Greece' 'Armenia' 'Unified Team' 'Hungary' 'Spain-1' 'Mongolia'
#  'Mexico' 'Norway-2' 'Norway-1' 'Italy-1' 'Puerto Rico-2' 'Puerto Rico'
#  'North Korea' 'China' 'Germany-3' 'Romania-2' 'Chile' 'Azerbaijan'
#  'Soviet Union-3' 'Andorra' 'Japan-2' 'Brazil' 'Austria-1' 'Austria-2'
#  'Bolivia' 'Canada-3' 'New Zealand' 'Lithuania' 'Latvia-2' 'Cyprus'
#  'Germany-1' 'Iceland' 'Latvia-1' 'West Germany-2' 'Bulgaria-1'
#  'Ukraine-2' 'Russia-3' 'United States-3' 'Slovakia'
#  'Bosnia and Herzegovina' 'East Germany-1' 'West Germany-1'
#  'East Germany-2' 'Moldova' 'Tonga' 'Guam' 'Ireland' 'Great Britain-3'
#  'Czechoslovakia-1' 'Czechoslovakia-2' 'San Marino' 'Spain-2' 'Slovenia'
#  'Unified Team-2' 'Liechtenstein' 'Israel-2' 'Algeria' 'Romania-1'
#  'Portugal' 'Italy-3' 'Monaco-1' 'Chinese Taipei' 'Venezuela'
#  'Puerto Rico-1' 'Czech Republic-2' 'Kenya' 'Kyrgyzstan' 'Unified Team-1'
#  'Bulgaria-2' 'South Africa' 'Belgium-1' 'Netherlands-2' 'Netherlands-1'
#  'Jamaica' 'Guatemala' 'Montenegro' 'Serbia' 'Nepal'
#  'United States Virgin Islands-2' 'United States Virgin Islands-1'
#  'Israel' 'Monaco-2' 'Costa Rica' 'Peru' 'Netherlands Antilles' 'Mexico-2'
#  'Israel-1' 'Chinese Taipei-1' 'Chinese Taipei-2' 'Poland-2' 'Poland-1'
#  'Philippines' 'British Virgin Islands' 'Macedonia' 'Czech Republic-1'
#  'Argentina-1' 'Belgium-2' 'France-3' 'Colombia' 'Australia-1' 'Dominica'
#  'Ireland-2' 'Serbia and Montenegro' 'Tajikistan' 'Egypt' 'Mexico-1'
#  'Hungary-1' 'Yugoslavia-1' 'Swaziland' 'Luxembourg' 'Senegal'
#  'Timor Leste' 'Unified Team-3' 'Ukraine-1' 'Hong Kong' 'Australia-2'
#  'Jamaica-2' 'New Zealand-1' 'Uruguay' 'Slovakia-1' 'South Korea-2'
#  'South Korea-1' 'Yugoslavia-2' 'East Germany-3'
#  'Individual Olympic Athletes' 'American Samoa' 'Luxembourg-2'
#  'Portugal-2' 'Paraguay' 'Ireland-1' 'Albania' 'Cameroon' 'Bermuda'
#  'Thailand' 'Hungary-2' 'Ghana' 'Uzbekistan-2' 'Honduras' 'China-2'
#  'China-1' 'Malta' 'New Zealand-2' 'Portugal-1' 'Madagascar'
#  'Uzbekistan-1' 'Fiji' 'China-3' 'Slovakia-2' 'Zimbabwe' 'Jamaica-1'
#  'West Germany-3' 'Ethiopia' 'Cayman Islands' 'Luxembourg-1']

# %%
d = {
    'Country':df["Team"],
    
}
 
df_new = pd.DataFrame(d,columns=['Country'])
df_unique_team = df_new.drop_duplicates()
df_unique_team
# Out:
#                Country
# 4          Netherlands
# 10       United States
# 28             Finland
# 59              Norway
# 119            Estonia
# ...                ...
# 229855       Jamaica-1
# 230596  West Germany-3
# 237404        Ethiopia
# 243073  Cayman Islands
# 257971    Luxembourg-1
#
# [221 rows x 1 columns]

# %%
sns.scatterplot(data=df, x=df["Year"], y=df["Age"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Age'>

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# 5       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# 6       Netherlands  NED  1992 Winter  1992  Winter     Albertville
# 7       Netherlands  NED  1992 Winter  1992  Winter     Albertville
# 8       Netherlands  NED  1994 Winter  1994  Winter     Lillehammer
# ...             ...  ...          ...   ...     ...             ...
# 271111     Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112       Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113       Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114       Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115       Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# 5       Speed Skating        Speed Skating Women's 1,000 metres   NaN
# 6       Speed Skating          Speed Skating Women's 500 metres   NaN
# 7       Speed Skating        Speed Skating Women's 1,000 metres   NaN
# 8       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [48564 rows x 15 columns]>

# %%
df.describe()
# Out:
#                  ID           Age        Height        Weight          Year
# count   48564.00000  48279.000000  40250.000000  39543.000000  48564.000000
# mean    69394.74930     25.039147    174.590112     70.759275   1987.825097
# std     38462.33521      4.777735      8.598176     12.213273     22.070100
# min         5.00000     11.000000    137.000000     32.000000   1924.000000
# 25%     37280.00000     22.000000    168.000000     62.000000   1972.000000
# 50%     67798.00000     24.000000    175.000000     70.000000   1994.000000
# 75%    103279.00000     28.000000    181.000000     79.000000   2006.000000
# max    135571.00000     58.000000    211.000000    145.000000   2014.000000

# %%
df4 = pd.unique(df['City'])
df4
# Out:
# array(['Calgary', 'Albertville', 'Lillehammer', 'Salt Lake City',
#        'Lake Placid', 'Sochi', 'Nagano', 'Torino', 'Squaw Valley',
#        'Innsbruck', 'Sarajevo', 'Oslo', "Cortina d'Ampezzo", 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
df2 = df.groupby(['Season', 'Year'])['Year'].count()
df2
# Out:
# Season  Year
# Winter  1924     460
#         1928     582
#         1932     352
#         1936     895
#         1948    1075
#         1952    1088
#         1956    1307
#         1960    1116
#         1964    1778
#         1968    1891
#         1972    1655
#         1976    1861
#         1980    1746
#         1984    2134
#         1988    2639
#         1992    3436
#         1994    3160
#         1998    3605
#         2002    4109
#         2006    4382
#         2010    4402
#         2014    4891
# Name: Year, dtype: int64

# %%
df1 = df.dropna()
df1
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 40          16   Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 60          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 61          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 63          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 64          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# ...        ...                        ...  ..   ...     ...     ...
# 270641  135355  Sergey Mikhaylovich Zubov   M  21.0   186.0    91.0
# 270827  135447                Matja Zupan   M  19.0   179.0    60.0
# 270876  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270878  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270886  135467          Silvan Zurbriggen   M  28.0   185.0    94.0
#
#                 Team  NOC        Games  Year  Season         City  \
# 40           Finland  FIN  2014 Winter  2014  Winter        Sochi
# 60            Norway  NOR  1992 Winter  1992  Winter  Albertville
# 61            Norway  NOR  1992 Winter  1992  Winter  Albertville
# 63            Norway  NOR  1994 Winter  1994  Winter  Lillehammer
# 64            Norway  NOR  1994 Winter  1994  Winter  Lillehammer
# ...              ...  ...          ...   ...     ...          ...
# 270641  Unified Team  EUN  1992 Winter  1992  Winter  Albertville
# 270827    Yugoslavia  YUG  1988 Winter  1988  Winter      Calgary
# 270876   Switzerland  SUI  1988 Winter  1988  Winter      Calgary
# 270878   Switzerland  SUI  1988 Winter  1988  Winter      Calgary
# 270886   Switzerland  SUI  2010 Winter  2010  Winter    Vancouver
#
#                 Sport                               Event   Medal
# 40         Ice Hockey         Ice Hockey Men's Ice Hockey  Bronze
# 60      Alpine Skiing         Alpine Skiing Men's Super G    Gold
# 61      Alpine Skiing    Alpine Skiing Men's Giant Slalom  Bronze
# 63      Alpine Skiing        Alpine Skiing Men's Downhill  Silver
# 64      Alpine Skiing         Alpine Skiing Men's Super G  Bronze
# ...               ...                                 ...     ...
# 270641     Ice Hockey         Ice Hockey Men's Ice Hockey    Gold
# 270827    Ski Jumping  Ski Jumping Men's Large Hill, Team  Silver
# 270876  Alpine Skiing        Alpine Skiing Men's Downhill    Gold
# 270878  Alpine Skiing    Alpine Skiing Men's Giant Slalom  Bronze
# 270886  Alpine Skiing        Alpine Skiing Men's Combined  Bronze
#
# [4840 rows x 15 columns]

# %%
df1.groupby(['Sport', 'Season'])['Height'].mean()
# Out:
# Sport                      Season
# Alpine Skiing              Winter    173.658192
# Biathlon                   Winter    174.528351
# Bobsleigh                  Winter    182.208481
# Cross Country Skiing       Winter    173.311499
# Curling                    Winter    174.267176
# Figure Skating             Winter    168.465587
# Freestyle Skiing           Winter    170.725490
# Ice Hockey                 Winter    178.830086
# Luge                       Winter    178.252809
# Nordic Combined            Winter    178.343066
# Short Track Speed Skating  Winter    169.686131
# Skeleton                   Winter    175.708333
# Ski Jumping                Winter    177.262857
# Snowboarding               Winter    173.561798
# Speed Skating              Winter    175.209016
# Name: Height, dtype: float64

# %%
df1.groupby(['Sport', 'Season'])['Weight'].mean()
# Out:
# Sport                      Season
# Alpine Skiing              Winter    72.782486
# Biathlon                   Winter    66.929124
# Bobsleigh                  Winter    90.077739
# Cross Country Skiing       Winter    65.823144
# Curling                    Winter    73.389313
# Figure Skating             Winter    60.194332
# Freestyle Skiing           Winter    67.362745
# Ice Hockey                 Winter    80.976617
# Luge                       Winter    79.207865
# Nordic Combined            Winter    67.189781
# Short Track Speed Skating  Winter    64.094891
# Skeleton                   Winter    71.083333
# Ski Jumping                Winter    62.920000
# Snowboarding               Winter    69.573034
# Speed Skating              Winter    71.245902
# Name: Weight, dtype: float64

# %%
st.title("Olympic medals database")
# Out:
# 2022-09-26 15:32:00.861
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\silbu\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
InputData = st.sidebar.selectbox("Select Medal", ("Gold", "Silver", "Bronze"))

# %%
Medalsselect = df[df["Medal"] == InputData]

# %%
st.dataframe(Medalsselect)
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
